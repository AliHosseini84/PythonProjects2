# %%
print ("Practice(is)")
# Out:
# Practice(is)

# %%
a = 1
b = 1
c = 2
d = 0
q = 8
R = 1

# %%
a is b
# Out:
# True

# %%
1 is 1
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ZARIN.COMPUTER\AppData\Local\Temp\ipykernel_19236\1728060598.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 1
# True

# %%
1 is 2
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ZARIN.COMPUTER\AppData\Local\Temp\ipykernel_19236\1180083856.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 2
# False

# %%
a is c
# Out:
# False

# %%
100 is 100
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ZARIN.COMPUTER\AppData\Local\Temp\ipykernel_19236\738435217.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   100 is 100
# True

# %%
c is d
# Out:
# False

# %%
a is a
# Out:
# True

# %%
a is 1
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ZARIN.COMPUTER\AppData\Local\Temp\ipykernel_19236\3222642818.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   a is 1
# True

# %%
c is 2
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ZARIN.COMPUTER\AppData\Local\Temp\ipykernel_19236\1172495297.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   c is 2
# True

# %%
d is 0
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ZARIN.COMPUTER\AppData\Local\Temp\ipykernel_19236\1736704892.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   d is 0
# True

# %%
8 is 8
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\ZARIN.COMPUTER\AppData\Local\Temp\ipykernel_19236\4248388793.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   8 is 8
# True

# %%
a = 2

# %%
a is a
# Out:
# True

# %%
q is a
# Out:
# False

# %%
a is R
# Out:
# False

# %%
R is a
# Out:
# False

# %%
a is b is R
# Out:
# False

# %%
type (R)
# Out:
# int

# %%
d is q
# Out:
# False
