# %%
print ('type')
# Out:
# type

# %%
a = 38
b = 24+17
c = 13.223
d = 17.5
h = 12.3+0.54
n = 'ali'
f = "amin"
y = True
e = False

# %%
type (a)
# Out:
# int

# %%
type (b)
# Out:
# int

# %%
type (c)
# Out:
# float

# %%
type (d)
# Out:
# float

# %%
type (h)
# Out:
# float

# %%
type (y)
# Out:
# bool

# %%
type (f)
# Out:
# str

# %%
type (e)
# Out:
# bool

# %%
type (False)
# Out:
# bool

# %%
type (True)
# Out:
# bool

# %%
type (100)
# Out:
# int

# %%
type (1.3)
# Out:
# float

# %%
type (d+h)
# Out:
# float

# %%
type (b)
# Out:
# int

# %%
type (a+f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 type (a+f)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
type (n+f)
# Out:
# str

# %%
type(h)
# Out:
# float

# %%
type(h+a)
# Out:
# float

# %%
type (a+b)
# Out:
# int

# %%
type (y+e)
# Out:
# int

# %%
type (a+y)
# Out:
# int

# %%
type ("amin")
# Out:
# str

# %%
type ("")
# Out:
# str

# %%
type (13.5)
# Out:
# float
