# %%
print ("Practice(Function)")
# Out:
# Practice(Function)

# %%
def jam(a,b):
    return a+b

# %%
jam (3,55)
# Out:
# 58

# %%
jam (1,3)
# Out:
# 4

# %%
def tav(s,r):
    return s**r

# %%
tav (45,0)
# Out:
# 1

# %%
tav(12,8)
# Out:
# 429981696

# %%
def taf (c,v):
    return c-v

# %%
taf (3322,3322)
# Out:
# 0

# %%
taf (3322,2233)
# Out:
# 1089

# %%
taf (12,34)
# Out:
# -22

# %%
def tagh (w,v):
    return w // v

# %%
tagh (10,5)
# Out:
# 2

# %%
tagh (19924,21421)
# Out:
# 0

# %%
tagh (9990,32)
# Out:
# 312

# %%
def zarb (i,o):
    return (i*o)

# %%
zarb (2,4)
# Out:
# 8

# %%
zarb (2,9)
# Out:
# 18

# %%
zarb (9,0)
# Out:
# 0

# %%
zarb (9655651654,2564681688616)
# Out:
# 24763672988668593370864

# %%
zarb (89988585986689,4)
# Out:
# 359954343946756

# %%
zarb (894568612389,0)
# Out:
# 0

# %%
def ZT (Z*X//T):
    return(Z,T)
# Out:
#   Cell In[40], line 1
#     def ZT (Z*X//T):
#              ^
# SyntaxError: invalid syntax

# %%
def ZT (Z,X,T):
    return(Z*X//T)

# %%
ZT (55,2,9)
# Out:
# 12

# %%
ZT (2,6,3)
# Out:
# 4

# %%
ZT (100,100,100)
# Out:
# 100

# %%
ZT (10,100,10)
# Out:
# 100

# %%
ZT (100,100,10)
# Out:
# 1000

# %%
ZT (100,100,1)
# Out:
# 10000

# %%
def ZT (Z,X,Z):
    return(Z*X//Z)
# Out:
#   Cell In[43], line 1
#     def ZT (Z,X,Z):
#                 ^
# SyntaxError: duplicate argument 'Z' in function definition
